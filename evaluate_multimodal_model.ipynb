# %% [markdown]
# # Multi-Modal Nutritional Deficiency Model Evaluation
#
# This notebook evaluates a trained multi-modal model for nutritional deficiency detection, focusing on multi-label classification metrics.

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.efficientnet import preprocess_input
from sklearn.metrics import (
    hamming_loss,
    accuracy_score,
    f1_score,
    roc_auc_score,
    precision_recall_curve,
    auc,
    classification_report,
    confusion_matrix
)

# Import our custom modules if they're needed for data loading
from data_mapper import NHANESImageMapper
from custom_data_generator import MultiModalDataGenerator

# Set random seeds for reproducibility
np.random.seed(42)
tf.random.set_seed(42)
# Out:
# WARNING:tensorflow:From c:\Users\Hency\OneDrive\Documents\mini proj\env\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %% [markdown]
# ## 2. Load the Trained Model

# %%
# Define the path to the saved model
model_path = r"C:\Users\Hency\OneDrive\Documents\mini proj\results\20250415-234926\final_nutritional_deficiency_model.h5"

# Check if the model file exists
if not os.path.exists(model_path):
    raise FileNotFoundError(f"Model file not found at {model_path}")
    
# Load the model
print(f"Loading model from {model_path}...")
model = load_model(model_path)
print("Model loaded successfully!")

# Print the model summary
model.summary()
# Out:
# Loading model from C:\Users\Hency\OneDrive\Documents\mini proj\results\20250415-234926\final_nutritional_deficiency_model.h5...
# WARNING:tensorflow:From c:\Users\Hency\OneDrive\Documents\mini proj\env\lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From c:\Users\Hency\OneDrive\Documents\mini proj\env\lib\site-packages\keras\src\layers\normalization\batch_normalization.py:979: The name tf.nn.fused_batch_norm is deprecated. Please use tf.compat.v1.nn.fused_batch_norm instead.
#
# Model loaded successfully!
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  img_input (InputLayer)      [(None, 224, 224, 3)]        0         []
#
#  rescaling_2 (Rescaling)     (None, 224, 224, 3)          0         ['img_input[0][0]']
#
#  normalization_1 (Normaliza  (None, 224, 224, 3)          7         ['rescaling_2[0][0]']
#  tion)
#
#  rescaling_3 (Rescaling)     (None, 224, 224, 3)          0         ['normalization_1[0][0]']
#
#  stem_conv_pad (ZeroPadding  (None, 225, 225, 3)          0         ['rescaling_3[0][0]']
#  2D)
#
#  stem_conv (Conv2D)          (None, 112, 112, 40)         1080      ['stem_conv_pad[0][0]']
#
#  stem_bn (BatchNormalizatio  (None, 112, 112, 40)         160       ['stem_conv[0][0]']
#  n)
#
#  stem_activation (Activatio  (None, 112, 112, 40)         0         ['stem_bn[0][0]']
#  n)
#
#  block1a_dwconv (DepthwiseC  (None, 112, 112, 40)         360       ['stem_activation[0][0]']
#  onv2D)
#
#  block1a_bn (BatchNormaliza  (None, 112, 112, 40)         160       ['block1a_dwconv[0][0]']
#  tion)
#
#  block1a_activation (Activa  (None, 112, 112, 40)         0         ['block1a_bn[0][0]']
#  tion)
#
#  block1a_se_squeeze (Global  (None, 40)                   0         ['block1a_activation[0][0]']
#  AveragePooling2D)
#
#  block1a_se_reshape (Reshap  (None, 1, 1, 40)             0         ['block1a_se_squeeze[0][0]']
#  e)
#
#  block1a_se_reduce (Conv2D)  (None, 1, 1, 10)             410       ['block1a_se_reshape[0][0]']
#
#  block1a_se_expand (Conv2D)  (None, 1, 1, 40)             440       ['block1a_se_reduce[0][0]']
#
#  block1a_se_excite (Multipl  (None, 112, 112, 40)         0         ['block1a_activation[0][0]',
#  y)                                                                  'block1a_se_expand[0][0]']
#
#  block1a_project_conv (Conv  (None, 112, 112, 24)         960       ['block1a_se_excite[0][0]']
#  2D)
#
#  block1a_project_bn (BatchN  (None, 112, 112, 24)         96        ['block1a_project_conv[0][0]']
#  ormalization)
#
#  block1b_dwconv (DepthwiseC  (None, 112, 112, 24)         216       ['block1a_project_bn[0][0]']
#  onv2D)
#
#  block1b_bn (BatchNormaliza  (None, 112, 112, 24)         96        ['block1b_dwconv[0][0]']
#  tion)
#
#  block1b_activation (Activa  (None, 112, 112, 24)         0         ['block1b_bn[0][0]']
#  tion)
#
#  block1b_se_squeeze (Global  (None, 24)                   0         ['block1b_activation[0][0]']
#  AveragePooling2D)
#
#  block1b_se_reshape (Reshap  (None, 1, 1, 24)             0         ['block1b_se_squeeze[0][0]']
#  e)
#
#  block1b_se_reduce (Conv2D)  (None, 1, 1, 6)              150       ['block1b_se_reshape[0][0]']
#
#  block1b_se_expand (Conv2D)  (None, 1, 1, 24)             168       ['block1b_se_reduce[0][0]']
#
#  block1b_se_excite (Multipl  (None, 112, 112, 24)         0         ['block1b_activation[0][0]',
#  y)                                                                  'block1b_se_expand[0][0]']
#
#  block1b_project_conv (Conv  (None, 112, 112, 24)         576       ['block1b_se_excite[0][0]']
#  2D)
#
#  block1b_project_bn (BatchN  (None, 112, 112, 24)         96        ['block1b_project_conv[0][0]']
#  ormalization)
#
#  block1b_drop (Dropout)      (None, 112, 112, 24)         0         ['block1b_project_bn[0][0]']
#
#  block1b_add (Add)           (None, 112, 112, 24)         0         ['block1b_drop[0][0]',
#                                                                      'block1a_project_bn[0][0]']
#
#  block2a_expand_conv (Conv2  (None, 112, 112, 144)        3456      ['block1b_add[0][0]']
#  D)
#
#  block2a_expand_bn (BatchNo  (None, 112, 112, 144)        576       ['block2a_expand_conv[0][0]']
#  rmalization)
#
#  block2a_expand_activation   (None, 112, 112, 144)        0         ['block2a_expand_bn[0][0]']
#  (Activation)
#
#  block2a_dwconv_pad (ZeroPa  (None, 113, 113, 144)        0         ['block2a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block2a_dwconv (DepthwiseC  (None, 56, 56, 144)          1296      ['block2a_dwconv_pad[0][0]']
#  onv2D)
#
#  block2a_bn (BatchNormaliza  (None, 56, 56, 144)          576       ['block2a_dwconv[0][0]']
#  tion)
#
#  block2a_activation (Activa  (None, 56, 56, 144)          0         ['block2a_bn[0][0]']
#  tion)
#
#  block2a_se_squeeze (Global  (None, 144)                  0         ['block2a_activation[0][0]']
#  AveragePooling2D)
#
#  block2a_se_reshape (Reshap  (None, 1, 1, 144)            0         ['block2a_se_squeeze[0][0]']
#  e)
#
#  block2a_se_reduce (Conv2D)  (None, 1, 1, 6)              870       ['block2a_se_reshape[0][0]']
#
#  block2a_se_expand (Conv2D)  (None, 1, 1, 144)            1008      ['block2a_se_reduce[0][0]']
#
#  block2a_se_excite (Multipl  (None, 56, 56, 144)          0         ['block2a_activation[0][0]',
#  y)                                                                  'block2a_se_expand[0][0]']
#
#  block2a_project_conv (Conv  (None, 56, 56, 32)           4608      ['block2a_se_excite[0][0]']
#  2D)
#
#  block2a_project_bn (BatchN  (None, 56, 56, 32)           128       ['block2a_project_conv[0][0]']
#  ormalization)
#
#  block2b_expand_conv (Conv2  (None, 56, 56, 192)          6144      ['block2a_project_bn[0][0]']
#  D)
#
#  block2b_expand_bn (BatchNo  (None, 56, 56, 192)          768       ['block2b_expand_conv[0][0]']
#  rmalization)
#
#  block2b_expand_activation   (None, 56, 56, 192)          0         ['block2b_expand_bn[0][0]']
#  (Activation)
#
#  block2b_dwconv (DepthwiseC  (None, 56, 56, 192)          1728      ['block2b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2b_bn (BatchNormaliza  (None, 56, 56, 192)          768       ['block2b_dwconv[0][0]']
#  tion)
#
#  block2b_activation (Activa  (None, 56, 56, 192)          0         ['block2b_bn[0][0]']
#  tion)
#
#  block2b_se_squeeze (Global  (None, 192)                  0         ['block2b_activation[0][0]']
#  AveragePooling2D)
#
#  block2b_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2b_se_squeeze[0][0]']
#  e)
#
#  block2b_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2b_se_reshape[0][0]']
#
#  block2b_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2b_se_reduce[0][0]']
#
#  block2b_se_excite (Multipl  (None, 56, 56, 192)          0         ['block2b_activation[0][0]',
#  y)                                                                  'block2b_se_expand[0][0]']
#
#  block2b_project_conv (Conv  (None, 56, 56, 32)           6144      ['block2b_se_excite[0][0]']
#  2D)
#
#  block2b_project_bn (BatchN  (None, 56, 56, 32)           128       ['block2b_project_conv[0][0]']
#  ormalization)
#
#  block2b_drop (Dropout)      (None, 56, 56, 32)           0         ['block2b_project_bn[0][0]']
#
#  block2b_add (Add)           (None, 56, 56, 32)           0         ['block2b_drop[0][0]',
#                                                                      'block2a_project_bn[0][0]']
#
#  block2c_expand_conv (Conv2  (None, 56, 56, 192)          6144      ['block2b_add[0][0]']
#  D)
#
#  block2c_expand_bn (BatchNo  (None, 56, 56, 192)          768       ['block2c_expand_conv[0][0]']
#  rmalization)
#
#  block2c_expand_activation   (None, 56, 56, 192)          0         ['block2c_expand_bn[0][0]']
#  (Activation)
#
#  block2c_dwconv (DepthwiseC  (None, 56, 56, 192)          1728      ['block2c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block2c_bn (BatchNormaliza  (None, 56, 56, 192)          768       ['block2c_dwconv[0][0]']
#  tion)
#
#  block2c_activation (Activa  (None, 56, 56, 192)          0         ['block2c_bn[0][0]']
#  tion)
#
#  block2c_se_squeeze (Global  (None, 192)                  0         ['block2c_activation[0][0]']
#  AveragePooling2D)
#
#  block2c_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block2c_se_squeeze[0][0]']
#  e)
#
#  block2c_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block2c_se_reshape[0][0]']
#
#  block2c_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block2c_se_reduce[0][0]']
#
#  block2c_se_excite (Multipl  (None, 56, 56, 192)          0         ['block2c_activation[0][0]',
#  y)                                                                  'block2c_se_expand[0][0]']
#
#  block2c_project_conv (Conv  (None, 56, 56, 32)           6144      ['block2c_se_excite[0][0]']
#  2D)
#
#  block2c_project_bn (BatchN  (None, 56, 56, 32)           128       ['block2c_project_conv[0][0]']
#  ormalization)
#
#  block2c_drop (Dropout)      (None, 56, 56, 32)           0         ['block2c_project_bn[0][0]']
#
#  block2c_add (Add)           (None, 56, 56, 32)           0         ['block2c_drop[0][0]',
#                                                                      'block2b_add[0][0]']
#
#  block3a_expand_conv (Conv2  (None, 56, 56, 192)          6144      ['block2c_add[0][0]']
#  D)
#
#  block3a_expand_bn (BatchNo  (None, 56, 56, 192)          768       ['block3a_expand_conv[0][0]']
#  rmalization)
#
#  block3a_expand_activation   (None, 56, 56, 192)          0         ['block3a_expand_bn[0][0]']
#  (Activation)
#
#  block3a_dwconv_pad (ZeroPa  (None, 59, 59, 192)          0         ['block3a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block3a_dwconv (DepthwiseC  (None, 28, 28, 192)          4800      ['block3a_dwconv_pad[0][0]']
#  onv2D)
#
#  block3a_bn (BatchNormaliza  (None, 28, 28, 192)          768       ['block3a_dwconv[0][0]']
#  tion)
#
#  block3a_activation (Activa  (None, 28, 28, 192)          0         ['block3a_bn[0][0]']
#  tion)
#
#  block3a_se_squeeze (Global  (None, 192)                  0         ['block3a_activation[0][0]']
#  AveragePooling2D)
#
#  block3a_se_reshape (Reshap  (None, 1, 1, 192)            0         ['block3a_se_squeeze[0][0]']
#  e)
#
#  block3a_se_reduce (Conv2D)  (None, 1, 1, 8)              1544      ['block3a_se_reshape[0][0]']
#
#  block3a_se_expand (Conv2D)  (None, 1, 1, 192)            1728      ['block3a_se_reduce[0][0]']
#
#  block3a_se_excite (Multipl  (None, 28, 28, 192)          0         ['block3a_activation[0][0]',
#  y)                                                                  'block3a_se_expand[0][0]']
#
#  block3a_project_conv (Conv  (None, 28, 28, 48)           9216      ['block3a_se_excite[0][0]']
#  2D)
#
#  block3a_project_bn (BatchN  (None, 28, 28, 48)           192       ['block3a_project_conv[0][0]']
#  ormalization)
#
#  block3b_expand_conv (Conv2  (None, 28, 28, 288)          13824     ['block3a_project_bn[0][0]']
#  D)
#
#  block3b_expand_bn (BatchNo  (None, 28, 28, 288)          1152      ['block3b_expand_conv[0][0]']
#  rmalization)
#
#  block3b_expand_activation   (None, 28, 28, 288)          0         ['block3b_expand_bn[0][0]']
#  (Activation)
#
#  block3b_dwconv (DepthwiseC  (None, 28, 28, 288)          7200      ['block3b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3b_bn (BatchNormaliza  (None, 28, 28, 288)          1152      ['block3b_dwconv[0][0]']
#  tion)
#
#  block3b_activation (Activa  (None, 28, 28, 288)          0         ['block3b_bn[0][0]']
#  tion)
#
#  block3b_se_squeeze (Global  (None, 288)                  0         ['block3b_activation[0][0]']
#  AveragePooling2D)
#
#  block3b_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3b_se_squeeze[0][0]']
#  e)
#
#  block3b_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3b_se_reshape[0][0]']
#
#  block3b_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3b_se_reduce[0][0]']
#
#  block3b_se_excite (Multipl  (None, 28, 28, 288)          0         ['block3b_activation[0][0]',
#  y)                                                                  'block3b_se_expand[0][0]']
#
#  block3b_project_conv (Conv  (None, 28, 28, 48)           13824     ['block3b_se_excite[0][0]']
#  2D)
#
#  block3b_project_bn (BatchN  (None, 28, 28, 48)           192       ['block3b_project_conv[0][0]']
#  ormalization)
#
#  block3b_drop (Dropout)      (None, 28, 28, 48)           0         ['block3b_project_bn[0][0]']
#
#  block3b_add (Add)           (None, 28, 28, 48)           0         ['block3b_drop[0][0]',
#                                                                      'block3a_project_bn[0][0]']
#
#  block3c_expand_conv (Conv2  (None, 28, 28, 288)          13824     ['block3b_add[0][0]']
#  D)
#
#  block3c_expand_bn (BatchNo  (None, 28, 28, 288)          1152      ['block3c_expand_conv[0][0]']
#  rmalization)
#
#  block3c_expand_activation   (None, 28, 28, 288)          0         ['block3c_expand_bn[0][0]']
#  (Activation)
#
#  block3c_dwconv (DepthwiseC  (None, 28, 28, 288)          7200      ['block3c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block3c_bn (BatchNormaliza  (None, 28, 28, 288)          1152      ['block3c_dwconv[0][0]']
#  tion)
#
#  block3c_activation (Activa  (None, 28, 28, 288)          0         ['block3c_bn[0][0]']
#  tion)
#
#  block3c_se_squeeze (Global  (None, 288)                  0         ['block3c_activation[0][0]']
#  AveragePooling2D)
#
#  block3c_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block3c_se_squeeze[0][0]']
#  e)
#
#  block3c_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block3c_se_reshape[0][0]']
#
#  block3c_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block3c_se_reduce[0][0]']
#
#  block3c_se_excite (Multipl  (None, 28, 28, 288)          0         ['block3c_activation[0][0]',
#  y)                                                                  'block3c_se_expand[0][0]']
#
#  block3c_project_conv (Conv  (None, 28, 28, 48)           13824     ['block3c_se_excite[0][0]']
#  2D)
#
#  block3c_project_bn (BatchN  (None, 28, 28, 48)           192       ['block3c_project_conv[0][0]']
#  ormalization)
#
#  block3c_drop (Dropout)      (None, 28, 28, 48)           0         ['block3c_project_bn[0][0]']
#
#  block3c_add (Add)           (None, 28, 28, 48)           0         ['block3c_drop[0][0]',
#                                                                      'block3b_add[0][0]']
#
#  block4a_expand_conv (Conv2  (None, 28, 28, 288)          13824     ['block3c_add[0][0]']
#  D)
#
#  block4a_expand_bn (BatchNo  (None, 28, 28, 288)          1152      ['block4a_expand_conv[0][0]']
#  rmalization)
#
#  block4a_expand_activation   (None, 28, 28, 288)          0         ['block4a_expand_bn[0][0]']
#  (Activation)
#
#  block4a_dwconv_pad (ZeroPa  (None, 29, 29, 288)          0         ['block4a_expand_activation[0]
#  dding2D)                                                           [0]']
#
#  block4a_dwconv (DepthwiseC  (None, 14, 14, 288)          2592      ['block4a_dwconv_pad[0][0]']
#  onv2D)
#
#  block4a_bn (BatchNormaliza  (None, 14, 14, 288)          1152      ['block4a_dwconv[0][0]']
#  tion)
#
#  block4a_activation (Activa  (None, 14, 14, 288)          0         ['block4a_bn[0][0]']
#  tion)
#
#  block4a_se_squeeze (Global  (None, 288)                  0         ['block4a_activation[0][0]']
#  AveragePooling2D)
#
#  block4a_se_reshape (Reshap  (None, 1, 1, 288)            0         ['block4a_se_squeeze[0][0]']
#  e)
#
#  block4a_se_reduce (Conv2D)  (None, 1, 1, 12)             3468      ['block4a_se_reshape[0][0]']
#
#  block4a_se_expand (Conv2D)  (None, 1, 1, 288)            3744      ['block4a_se_reduce[0][0]']
#
#  block4a_se_excite (Multipl  (None, 14, 14, 288)          0         ['block4a_activation[0][0]',
#  y)                                                                  'block4a_se_expand[0][0]']
#
#  block4a_project_conv (Conv  (None, 14, 14, 96)           27648     ['block4a_se_excite[0][0]']
#  2D)
#
#  block4a_project_bn (BatchN  (None, 14, 14, 96)           384       ['block4a_project_conv[0][0]']
#  ormalization)
#
#  block4b_expand_conv (Conv2  (None, 14, 14, 576)          55296     ['block4a_project_bn[0][0]']
#  D)
#
#  block4b_expand_bn (BatchNo  (None, 14, 14, 576)          2304      ['block4b_expand_conv[0][0]']
#  rmalization)
#
#  block4b_expand_activation   (None, 14, 14, 576)          0         ['block4b_expand_bn[0][0]']
#  (Activation)
#
#  block4b_dwconv (DepthwiseC  (None, 14, 14, 576)          5184      ['block4b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4b_bn (BatchNormaliza  (None, 14, 14, 576)          2304      ['block4b_dwconv[0][0]']
#  tion)
#
#  block4b_activation (Activa  (None, 14, 14, 576)          0         ['block4b_bn[0][0]']
#  tion)
#
#  block4b_se_squeeze (Global  (None, 576)                  0         ['block4b_activation[0][0]']
#  AveragePooling2D)
#
#  block4b_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block4b_se_squeeze[0][0]']
#  e)
#
#  block4b_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block4b_se_reshape[0][0]']
#
#  block4b_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block4b_se_reduce[0][0]']
#
#  block4b_se_excite (Multipl  (None, 14, 14, 576)          0         ['block4b_activation[0][0]',
#  y)                                                                  'block4b_se_expand[0][0]']
#
#  block4b_project_conv (Conv  (None, 14, 14, 96)           55296     ['block4b_se_excite[0][0]']
#  2D)
#
#  block4b_project_bn (BatchN  (None, 14, 14, 96)           384       ['block4b_project_conv[0][0]']
#  ormalization)
#
#  block4b_drop (Dropout)      (None, 14, 14, 96)           0         ['block4b_project_bn[0][0]']
#
#  block4b_add (Add)           (None, 14, 14, 96)           0         ['block4b_drop[0][0]',
#                                                                      'block4a_project_bn[0][0]']
#
#  block4c_expand_conv (Conv2  (None, 14, 14, 576)          55296     ['block4b_add[0][0]']
#  D)
#
#  block4c_expand_bn (BatchNo  (None, 14, 14, 576)          2304      ['block4c_expand_conv[0][0]']
#  rmalization)
#
#  block4c_expand_activation   (None, 14, 14, 576)          0         ['block4c_expand_bn[0][0]']
#  (Activation)
#
#  block4c_dwconv (DepthwiseC  (None, 14, 14, 576)          5184      ['block4c_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4c_bn (BatchNormaliza  (None, 14, 14, 576)          2304      ['block4c_dwconv[0][0]']
#  tion)
#
#  block4c_activation (Activa  (None, 14, 14, 576)          0         ['block4c_bn[0][0]']
#  tion)
#
#  block4c_se_squeeze (Global  (None, 576)                  0         ['block4c_activation[0][0]']
#  AveragePooling2D)
#
#  block4c_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block4c_se_squeeze[0][0]']
#  e)
#
#  block4c_se_reduce (Conv2D)  (None, 1, 1, 24)             13848     ['block4c_se_reshape[0][0]']
#
#  block4c_se_expand (Conv2D)  (None, 1, 1, 576)            14400     ['block4c_se_reduce[0][0]']
#
#  block4c_se_excite (Multipl  (None, 14, 14, 576)          0         ['block4c_activation[0][0]',
#  y)                                                                  'block4c_se_expand[0][0]']
#
#  block4c_project_conv (Conv  (None, 14, 14, 96)           55296     ['block4c_se_excite[0][0]']
#  2D)
#
#  block4c_project_bn (BatchN  (None, 14, 14, 96)           384       ['block4c_project_conv[0][0]']
#  ormalization)
#
#  block4c_drop (Dropout)      (None, 14, 14, 96)           0         ['block4c_project_bn[0][0]']
#
#  block4c_add (Add)           (None, 14, 14, 96)           0         ['block4c_drop[0][0]',
#                                                                      'block4b_add[0][0]']
#
#  block4d_expand_conv (Conv2  (None, 14, 14, 576)          55296     ['block4c_add[0][0]']
#  D)
#
#  block4d_expand_bn (BatchNo  (None, 14, 14, 576)          2304      ['block4d_expand_conv[0][0]']
#  rmalization)
#
#  block4d_expand_activation   (None, 14, 14, 576)          0         ['block4d_expand_bn[0][0]']
#  (Activation)
#
#  block4d_dwconv (DepthwiseC  (None, 14, 14, 576)          5184      ['block4d_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block4d_bn (BatchNormaliza  (None, 14, 14, 576)          2304      ['block4d_dwconv[0][0]']
#  tion)
#
#  block4d_activation (Activa  (None, 14, 14, 576)          0         ['block4d_bn[0][0]']
#  tion)
#
#  block4d_se_squeeze (Global  (None, 576)                  0         ['block4d_activation[0][0]']
#  AveragePooling2D)
#
#  block4d_se_reshape (Reshap  (None, 1, 1, 576)            0         ['block4d_se_squeeze[0][0]']
# ...
#  block6f_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block6f_se_reshape[0][0]']
#
#  block6f_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block6f_se_reduce[0][0]']
#
#  block6f_se_excite (Multipl  (None, 7, 7, 1392)           0         ['block6f_activation[0][0]',
#  y)                                                                  'block6f_se_expand[0][0]']
#
#  block6f_project_conv (Conv  (None, 7, 7, 232)            322944    ['block6f_se_excite[0][0]']
#  2D)
#
#  block6f_project_bn (BatchN  (None, 7, 7, 232)            928       ['block6f_project_conv[0][0]']
#  ormalization)
#
#  block6f_drop (Dropout)      (None, 7, 7, 232)            0         ['block6f_project_bn[0][0]']
#
#  block6f_add (Add)           (None, 7, 7, 232)            0         ['block6f_drop[0][0]',
#                                                                      'block6e_add[0][0]']
#
#  block7a_expand_conv (Conv2  (None, 7, 7, 1392)           322944    ['block6f_add[0][0]']
#  D)
#
#  block7a_expand_bn (BatchNo  (None, 7, 7, 1392)           5568      ['block7a_expand_conv[0][0]']
#  rmalization)
#
#  block7a_expand_activation   (None, 7, 7, 1392)           0         ['block7a_expand_bn[0][0]']
#  (Activation)
#
#  block7a_dwconv (DepthwiseC  (None, 7, 7, 1392)           12528     ['block7a_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7a_bn (BatchNormaliza  (None, 7, 7, 1392)           5568      ['block7a_dwconv[0][0]']
#  tion)
#
#  block7a_activation (Activa  (None, 7, 7, 1392)           0         ['block7a_bn[0][0]']
#  tion)
#
#  block7a_se_squeeze (Global  (None, 1392)                 0         ['block7a_activation[0][0]']
#  AveragePooling2D)
#
#  block7a_se_reshape (Reshap  (None, 1, 1, 1392)           0         ['block7a_se_squeeze[0][0]']
#  e)
#
#  block7a_se_reduce (Conv2D)  (None, 1, 1, 58)             80794     ['block7a_se_reshape[0][0]']
#
#  block7a_se_expand (Conv2D)  (None, 1, 1, 1392)           82128     ['block7a_se_reduce[0][0]']
#
#  block7a_se_excite (Multipl  (None, 7, 7, 1392)           0         ['block7a_activation[0][0]',
#  y)                                                                  'block7a_se_expand[0][0]']
#
#  block7a_project_conv (Conv  (None, 7, 7, 384)            534528    ['block7a_se_excite[0][0]']
#  2D)
#
#  block7a_project_bn (BatchN  (None, 7, 7, 384)            1536      ['block7a_project_conv[0][0]']
#  ormalization)
#
#  block7b_expand_conv (Conv2  (None, 7, 7, 2304)           884736    ['block7a_project_bn[0][0]']
#  D)
#
#  block7b_expand_bn (BatchNo  (None, 7, 7, 2304)           9216      ['block7b_expand_conv[0][0]']
#  rmalization)
#
#  block7b_expand_activation   (None, 7, 7, 2304)           0         ['block7b_expand_bn[0][0]']
#  (Activation)
#
#  block7b_dwconv (DepthwiseC  (None, 7, 7, 2304)           20736     ['block7b_expand_activation[0]
#  onv2D)                                                             [0]']
#
#  block7b_bn (BatchNormaliza  (None, 7, 7, 2304)           9216      ['block7b_dwconv[0][0]']
#  tion)
#
#  block7b_activation (Activa  (None, 7, 7, 2304)           0         ['block7b_bn[0][0]']
#  tion)
#
#  block7b_se_squeeze (Global  (None, 2304)                 0         ['block7b_activation[0][0]']
#  AveragePooling2D)
#
#  block7b_se_reshape (Reshap  (None, 1, 1, 2304)           0         ['block7b_se_squeeze[0][0]']
#  e)
#
#  block7b_se_reduce (Conv2D)  (None, 1, 1, 96)             221280    ['block7b_se_reshape[0][0]']
#
#  block7b_se_expand (Conv2D)  (None, 1, 1, 2304)           223488    ['block7b_se_reduce[0][0]']
#
#  block7b_se_excite (Multipl  (None, 7, 7, 2304)           0         ['block7b_activation[0][0]',
#  y)                                                                  'block7b_se_expand[0][0]']
#
#  block7b_project_conv (Conv  (None, 7, 7, 384)            884736    ['block7b_se_excite[0][0]']
#  2D)
#
#  block7b_project_bn (BatchN  (None, 7, 7, 384)            1536      ['block7b_project_conv[0][0]']
#  ormalization)
#
#  block7b_drop (Dropout)      (None, 7, 7, 384)            0         ['block7b_project_bn[0][0]']
#
#  block7b_add (Add)           (None, 7, 7, 384)            0         ['block7b_drop[0][0]',
#                                                                      'block7a_project_bn[0][0]']
#
#  tabular_input (InputLayer)  [(None, 20)]                 0         []
#
#  top_conv (Conv2D)           (None, 7, 7, 1536)           589824    ['block7b_add[0][0]']
#
#  dense_6 (Dense)             (None, 128)                  2688      ['tabular_input[0][0]']
#
#  top_bn (BatchNormalization  (None, 7, 7, 1536)           6144      ['top_conv[0][0]']
#  )
#
#  batch_normalization_5 (Bat  (None, 128)                  512       ['dense_6[0][0]']
#  chNormalization)
#
#  top_activation (Activation  (None, 7, 7, 1536)           0         ['top_bn[0][0]']
#  )
#
#  dropout_4 (Dropout)         (None, 128)                  0         ['batch_normalization_5[0][0]'
#                                                                     ]
#
#  global_average_pooling2d_1  (None, 1536)                 0         ['top_activation[0][0]']
#   (GlobalAveragePooling2D)
#
#  dense_7 (Dense)             (None, 64)                   8256      ['dropout_4[0][0]']
#
#  dense_8 (Dense)             (None, 64)                   98368     ['global_average_pooling2d_1[0
#                                                                     ][0]']
#
#  batch_normalization_6 (Bat  (None, 64)                   256       ['dense_7[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 64)                   256       ['dense_8[0][0]']
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                   0         ['batch_normalization_6[0][0]'
#                                                                     ]
#
#  dropout_6 (Dropout)         (None, 64)                   0         ['batch_normalization_7[0][0]'
#                                                                     ]
#
#  tabular_features (Dense)    (None, 32)                   2080      ['dropout_5[0][0]']
#
#  image_features (Dense)      (None, 32)                   2080      ['dropout_6[0][0]']
#
#  concatenate_1 (Concatenate  (None, 64)                   0         ['tabular_features[0][0]',
#  )                                                                   'image_features[0][0]']
#
#  dense_9 (Dense)             (None, 64)                   4160      ['concatenate_1[0][0]']
#
#  batch_normalization_8 (Bat  (None, 64)                   256       ['dense_9[0][0]']
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                   0         ['batch_normalization_8[0][0]'
#                                                                     ]
#
#  dense_10 (Dense)            (None, 32)                   2080      ['dropout_7[0][0]']
#
#  batch_normalization_9 (Bat  (None, 32)                   128       ['dense_10[0][0]']
#  chNormalization)
#
#  dense_11 (Dense)            (None, 23)                   759       ['batch_normalization_9[0][0]'
#                                                                     ]
#
# ==================================================================================================
# Total params: 10905414 (41.60 MB)
# Trainable params: 121175 (473.34 KB)
# Non-trainable params: 10784239 (41.14 MB)
# __________________________________________________________________________________________________

# %% [markdown]
# ## 3. Define the Deficiency Labels

# %%
# Define the names of nutritional deficiency categories
deficiency_names = [
    "Vitamin A Deficiency", "Vitamin B1 Deficiency", "Vitamin B2 Deficiency",
    "Vitamin B3 Deficiency", "Vitamin B5 Deficiency", "Vitamin B6 Deficiency",
    "Vitamin B7 Deficiency", "Vitamin B9 Deficiency", "Vitamin B12 Deficiency",
    "Vitamin C Deficiency", "Vitamin D Deficiency", "Vitamin E Deficiency",
    "Vitamin K Deficiency", "Calcium Deficiency", "Iron Deficiency",
    "Magnesium Deficiency", "Zinc Deficiency", "Protein Deficiency",
    "Omega-3 Fatty Acid Deficiency", "Iodine Deficiency", "Selenium Deficiency",
    "Potassium Deficiency", "Multiple Deficiencies"
]

print(f"Loaded {len(deficiency_names)} deficiency categories")
# Out:
# Loaded 23 deficiency categories

# %% [markdown]
# ## 4. Load and Prepare Test Data

# %%
# Create the NHANES-Image mapper to load the dataset
print("Creating NHANES-Image mapper...")
mapper = NHANESImageMapper(
    nhanes_dir="dataset/NHANES",
    image_dir="dataset/Image data"
)

# Load NHANES data
nhanes_data = mapper.load_nhanes_data()
print(f"Loaded NHANES data with {len(nhanes_data)} records")

# Create paired dataset
print("Creating paired dataset...")
paired_dataset = mapper.create_paired_dataset(test_size=0.2)
print(f"Created paired dataset with {len(paired_dataset['test'])} testing samples")

# Extract the test data
test_data = paired_dataset['test']
num_classes = paired_dataset['num_classes']
print(f"Number of classes: {num_classes}")

# Create a test generator
batch_size = 16
test_generator = MultiModalDataGenerator(
    dataset=test_data,
    batch_size=batch_size,
    image_size=(224, 224),
    shuffle=False,
    augment=False,
    num_classes=num_classes
)

print(f"Created test generator with {len(test_generator)} batches")
# Out:
# Creating NHANES-Image mapper...
# Diet data columns: ['SEQN', 'WTDRD1', 'WTDR2D', 'DR1DRSTZ', 'DR1EXMER', 'DRABF', 'DRDINT', 'DR1DBIH', 'DR1DAY', 'DR1LANG'] ...
# Using diet columns: ['DR1TKCAL', 'DR1TPROT', 'DR1TCARB', 'DR1TTFAT', 'DR1DAY', 'DR1DBIH', 'WTDRD1', 'WTDR2D']
# Using lab columns: ['LBXSCH', 'LBXTC', 'LBXSGL']
# Using examination columns: ['BMXBMI', 'BPXSY1', 'BPXDI1', 'BMXWT', 'BMXHT']
# Using demographic columns: ['RIAGENDR', 'RIDAGEYR', 'RIDRETH1', 'DMDEDUC2']
# Merged data shape: (9813, 21)
# Merged data columns: ['SEQN', 'DR1TKCAL', 'DR1TPROT', 'DR1TCARB', 'DR1TTFAT', 'DR1DAY', 'DR1DBIH', 'WTDRD1', 'WTDR2D', 'LBXSCH', 'LBXTC', 'LBXSGL', 'BMXBMI', 'BPXSY1', 'BPXDI1', 'BMXWT', 'BMXHT', 'RIAGENDR', 'RIDAGEYR', 'RIDRETH1', 'DMDEDUC2']
# Loaded NHANES data with 9813 records
# Creating paired dataset...
# Created paired dataset with 1963 testing samples
# Number of classes: 23
# Created test generator with 123 batches

# %% [markdown]
# ## 5. Generate Predictions

# %%
# Function to generate all predictions
def generate_all_predictions(model, data_generator):
    print("Generating predictions...")
    # Initialize arrays to store predictions and true labels
    all_predictions = []
    all_true_labels = []
    
    # Process each batch
    for i in range(len(data_generator)):
        if i % 10 == 0:
            pass# print(f"Processing batch {i+1}/{len(data_generator)}")
            
        # Get the batch inputs and labels
        inputs, labels = data_generator[i]
        
        # Get model predictions for this batch
        batch_predictions = model.predict(inputs, verbose=0)
        
        # Store predictions and true labels
        all_predictions.append(batch_predictions)
        all_true_labels.append(labels)
    
    # Concatenate batch results
    y_pred_probs = np.vstack(all_predictions)
    y_true = np.vstack(all_true_labels)
    print(all_predictions)
    print(f"Generated predictions for {y_pred_probs.shape[0]} samples")
    return y_pred_probs, y_true

# Generate predictions
y_pred_probs, y_true = generate_all_predictions(model, test_generator)

# Convert probabilities to binary predictions using a threshold of 0.5
y_pred_binary = (y_pred_probs >= 0.5).astype(int)

# Also get class-wise predictions (for traditional classification metrics)
y_pred_classes = np.argmax(y_pred_probs, axis=1)
y_true_classes = np.argmax(y_true, axis=1)
# Out:
# Generating predictions...
# [array([[7.79074850e-03, 9.49963578e-04, 2.85467945e-06, 3.13574856e-06,
#         3.73265357e-04, 7.52203353e-03, 4.10364873e-06, 2.02170122e-04,
#         3.09356983e-06, 7.99853131e-02, 2.78718949e-06, 1.61865091e-06,
#         3.10821524e-05, 3.95295638e-06, 8.26082134e-04, 2.13882709e-06,
#         2.33186915e-06, 9.02278721e-01, 2.43359091e-06, 2.09454583e-06,
#         3.19559581e-06, 4.16431021e-06, 2.78240395e-06],
#        [4.68953294e-05, 5.17987610e-05, 6.82120245e-08, 5.62429783e-08,
#         4.75469120e-02, 1.09375780e-03, 6.88034305e-08, 1.52546099e-05,
#         6.80900953e-08, 1.67244661e-03, 7.58780487e-08, 4.64941188e-08,
#         3.12970427e-04, 1.30685805e-07, 9.49105918e-01, 5.09201463e-08,
#         5.92805982e-08, 1.53068177e-04, 4.66711931e-08, 3.98922815e-08,
#         9.92475293e-08, 9.12154761e-08, 5.53154891e-08],
#         5.82206803e-06, 4.32373792e-01, 7.36662332e-06, 4.88799469e-06,
#         2.08304706e-03, 9.22822619e-06, 6.91422087e-04, 4.94282676e-06,
#         4.95806671e-06, 5.40599763e-01, 7.98607562e-06, 6.48633932e-06,
#         7.58732085e-06, 1.03782477e-05, 5.38228505e-06],
#        [5.39497181e-04, 5.33107144e-04, 3.49235893e-06, 4.28915837e-06,
#         7.98600256e-01, 1.27567037e-04, 6.56386692e-06, 3.72421899e-04,
#         5.71468763e-06, 8.79325159e-03, 5.31303203e-06, 2.55758277e-06,
#         8.21035574e-05, 9.48135585e-06, 1.80015653e-01, 3.80326469e-06,
#         3.17617719e-06, 1.08712716e-02, 3.41967370e-06, 4.07111520e-06,
#         3.50617461e-06, 5.91846810e-06, 3.65165602e-06],
#        [1.85821900e-05, 9.96049403e-06, 2.07343896e-06, 2.08636175e-06,
#         1.38292432e-06, 2.96650047e-04, 3.01786054e-06, 3.92291840e-05,
#         2.84135695e-06, 7.30278771e-06, 2.93514040e-06, 2.14453530e-06,
#         9.99564111e-01, 2.69559428e-06, 2.10730013e-06, 1.53707265e-06,
#         2.60960701e-06, 2.55906525e-05, 2.77136587e-06, 1.89077423e-06,
#         2.52931318e-06, 3.08697076e-06, 2.77739309e-06],
#        [1.08033861e-03, 1.16232106e-04, 3.90233345e-06, 4.46479862e-06,
#         9.27174624e-05, 1.56047428e-03, 5.01006571e-06, 9.10845459e-01,
#         4.58337172e-06, 6.39971695e-05, 5.14212888e-06, 3.71254851e-06,
#         8.60448405e-02, 6.70949748e-06, 9.56123840e-05, 5.83996780e-06,
#         5.70905559e-06, 2.98105333e-05, 3.91161120e-06, 3.61948833e-06,
#         6.46556236e-06, 5.44256682e-06, 5.88533339e-06],
#        [9.41178369e-05, 4.70492669e-04, 1.70301632e-07, 2.91567602e-07,
#         1.69836232e-04, 2.71326251e-04, 5.63381320e-07, 8.29951896e-05,
#         2.66134919e-07, 2.03973174e-01, 3.20156545e-07, 1.12199828e-07,
#         5.19965361e-05, 3.93196984e-07, 1.82338423e-04, 2.74081174e-07,
#         1.85928940e-07, 7.94699669e-01, 2.33305897e-07, 2.92229316e-07,
#         3.25149273e-07, 3.44079126e-07, 2.83019659e-07]], dtype=float32)]
# Generated predictions for 1963 samples

# %% [markdown]
# ## 6. Implement and Calculate Evaluation Metrics

# %%
# 1. Hamming Loss
hamming_loss_value = hamming_loss(y_true, y_pred_binary)

# 2. Subset Accuracy (Exact Match Ratio)
def subset_accuracy(y_true, y_pred):
    # Check if all predictions match for each sample
    exact_match = np.all(y_true == y_pred, axis=1)
    # Return the proportion of samples with exact matches
    return np.mean(exact_match)

subset_accuracy_value = subset_accuracy(y_true, y_pred_binary)

# 3. Micro-Averaged F1 Score
micro_f1 = f1_score(y_true.flatten(), y_pred_binary.flatten(), average='micro')

# 4. Macro-Averaged ROC-AUC Score
# Handle case where some classes might not have samples in the test set
try:
    macro_roc_auc = roc_auc_score(y_true, y_pred_probs, average='macro')
except ValueError as e:
    print(f"Warning when calculating ROC AUC: {e}")
    # Calculate for each class where possible and then average
    class_roc_aucs = []
    for i in range(y_true.shape[1]):
        if len(np.unique(y_true[:, i])) > 1:  # Check if class has multiple values
            try:
                class_roc_aucs.append(roc_auc_score(y_true[:, i], y_pred_probs[:, i]))
            except Exception:
                pass
    macro_roc_auc = np.mean(class_roc_aucs) if class_roc_aucs else float('nan')

# 5. Macro-Averaged Precision-Recall AUC
def macro_precision_recall_auc(y_true, y_pred_probs):
    pr_aucs = []
    for i in range(y_true.shape[1]):
        if len(np.unique(y_true[:, i])) > 1:  # Check if class has multiple values
            try:
                precision, recall, _ = precision_recall_curve(y_true[:, i], y_pred_probs[:, i])
                pr_aucs.append(auc(recall, precision))
            except Exception:
                pass
    return np.mean(pr_aucs) if pr_aucs else float('nan')

macro_pr_auc = macro_precision_recall_auc(y_true, y_pred_probs)

# Accuracy (based on most likely class)
accuracy = accuracy_score(y_true_classes, y_pred_classes)

# Calculate additional metrics for comprehensive evaluation
macro_f1 = f1_score(y_true_classes, y_pred_classes, average='macro')
weighted_f1 = f1_score(y_true_classes, y_pred_classes, average='weighted')

# %% [markdown]
# ## 7. Display Metrics

# %%
# Create a DataFrame to display metrics
metrics_df = pd.DataFrame([
    ["Hamming Loss", hamming_loss_value, "Lower is better"],
    ["Subset Accuracy (Exact Match Ratio)", subset_accuracy_value, "Higher is better"],
    ["Micro-Averaged F1 Score", micro_f1, "Higher is better"],
    ["Macro-Averaged Precision-Recall AUC", macro_pr_auc, "Higher is better"],
    ["Accuracy (Most Likely Class)", accuracy, "Higher is better"],
    ["Macro-Averaged F1 Score", macro_f1, "Higher is better"],
    ["Weighted F1 Score", weighted_f1, "Higher is better"]
], columns=["Metric", "Value", "Interpretation"])

# Style the DataFrame
styled_metrics = metrics_df.style.set_properties(**{
    'text-align': 'left',
    'border': '1px solid black',
    'padding': '5px'
}).format({"Value": "{:.4f}"})

# Display metrics
display(styled_metrics)

# Print a summary
print("\nModel Evaluation Summary:")
print(f"The model achieves an accuracy of {accuracy:.2%} for the most likely class.")
print(f"The hamming loss of {hamming_loss_value:.4f} indicates the proportion of misclassified labels.")
print(f"The subset accuracy of {subset_accuracy_value:.2%} shows the percentage of samples where all labels are correctly predicted.")
# Out:
# <style type="text/css">
# #T_487e5_row0_col0, #T_487e5_row0_col1, #T_487e5_row0_col2, #T_487e5_row1_col0, #T_487e5_row1_col1, #T_487e5_row1_col2, #T_487e5_row2_col0, #T_487e5_row2_col1, #T_487e5_row2_col2, #T_487e5_row3_col0, #T_487e5_row3_col1, #T_487e5_row3_col2, #T_487e5_row4_col0, #T_487e5_row4_col1, #T_487e5_row4_col2, #T_487e5_row5_col0, #T_487e5_row5_col1, #T_487e5_row5_col2, #T_487e5_row6_col0, #T_487e5_row6_col1, #T_487e5_row6_col2 {
#   text-align: left;
#   border: 1px solid black;
#   padding: 5px;
# }
# </style>
# <table id="T_487e5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_487e5_level0_col0" class="col_heading level0 col0" >Metric</th>
#       <th id="T_487e5_level0_col1" class="col_heading level0 col1" >Value</th>
#       <th id="T_487e5_level0_col2" class="col_heading level0 col2" >Interpretation</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_487e5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_487e5_row0_col0" class="data row0 col0" >Hamming Loss</td>
#       <td id="T_487e5_row0_col1" class="data row0 col1" >0.0158</td>
#       <td id="T_487e5_row0_col2" class="data row0 col2" >Lower is better</td>
#     </tr>
#     <tr>
#       <th id="T_487e5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_487e5_row1_col0" class="data row1 col0" >Subset Accuracy (Exact Match Ratio)</td>
#       <td id="T_487e5_row1_col1" class="data row1 col1" >0.7906</td>
#       <td id="T_487e5_row1_col2" class="data row1 col2" >Higher is better</td>
#     </tr>
#     <tr>
#       <th id="T_487e5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_487e5_row2_col0" class="data row2 col0" >Micro-Averaged F1 Score</td>
#       <td id="T_487e5_row2_col1" class="data row2 col1" >0.9842</td>
#       <td id="T_487e5_row2_col2" class="data row2 col2" >Higher is better</td>
#     </tr>
#     <tr>
#       <th id="T_487e5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_487e5_row3_col0" class="data row3 col0" >Macro-Averaged Precision-Recall AUC</td>
#       <td id="T_487e5_row3_col1" class="data row3 col1" >0.8689</td>
#       <td id="T_487e5_row3_col2" class="data row3 col2" >Higher is better</td>
#     </tr>
#     <tr>
#       <th id="T_487e5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_487e5_row4_col0" class="data row4 col0" >Accuracy (Most Likely Class)</td>
#       <td id="T_487e5_row4_col1" class="data row4 col1" >0.8110</td>
#       <td id="T_487e5_row4_col2" class="data row4 col2" >Higher is better</td>
#     </tr>
#     <tr>
#       <th id="T_487e5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_487e5_row5_col0" class="data row5 col0" >Macro-Averaged F1 Score</td>
#       <td id="T_487e5_row5_col1" class="data row5 col1" >0.7807</td>
#       <td id="T_487e5_row5_col2" class="data row5 col2" >Higher is better</td>
#     </tr>
#     <tr>
#       <th id="T_487e5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_487e5_row6_col0" class="data row6 col0" >Weighted F1 Score</td>
#       <td id="T_487e5_row6_col1" class="data row6 col1" >0.8089</td>
#       <td id="T_487e5_row6_col2" class="data row6 col2" >Higher is better</td>
#     </tr>
#   </tbody>
# </table>
# Model Evaluation Summary:
# The model achieves an accuracy of 81.10% for the most likely class.
# The hamming loss of 0.0158 indicates the proportion of misclassified labels.
# The subset accuracy of 79.06% shows the percentage of samples where all labels are correctly predicted.

# %% [markdown]
# ## 8. Generate Detailed Classification Report

# %%
# Get unique classes in y_true_classes
unique_classes = np.unique(y_true_classes)

# Adjust target_names to match the unique classes
adjusted_target_names = [deficiency_names[i][:15] + '...' if len(deficiency_names[i]) > 15 else deficiency_names[i] for i in unique_classes]

# Get classification report for single-label prediction (most likely class)
class_report = classification_report(y_true_classes, y_pred_classes, target_names=adjusted_target_names, output_dict=True)

# Convert to DataFrame for better visualization
class_report_df = pd.DataFrame(class_report).transpose()

# Display the classification report
display(class_report_df.style.set_caption("Classification Report").format(precision=2))
# Out:
# <style type="text/css">
# </style>
# <table id="T_09241">
#   <caption>Classification Report</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_09241_level0_col0" class="col_heading level0 col0" >precision</th>
#       <th id="T_09241_level0_col1" class="col_heading level0 col1" >recall</th>
#       <th id="T_09241_level0_col2" class="col_heading level0 col2" >f1-score</th>
#       <th id="T_09241_level0_col3" class="col_heading level0 col3" >support</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09241_level0_row0" class="row_heading level0 row0" >Vitamin A Defic...</th>
#       <td id="T_09241_row0_col0" class="data row0 col0" >0.70</td>
#       <td id="T_09241_row0_col1" class="data row0 col1" >0.78</td>
#       <td id="T_09241_row0_col2" class="data row0 col2" >0.74</td>
#       <td id="T_09241_row0_col3" class="data row0 col3" >96.00</td>
#     </tr>
#     <tr>
#       <th id="T_09241_level0_row1" class="row_heading level0 row1" >Vitamin B1 Defi...</th>
#       <td id="T_09241_row1_col0" class="data row1 col0" >0.74</td>
#       <td id="T_09241_row1_col1" class="data row1 col1" >0.79</td>
#       <td id="T_09241_row1_col2" class="data row1 col2" >0.77</td>
#       <td id="T_09241_row1_col3" class="data row1 col3" >29.00</td>
#     </tr>
#     <tr>
#       <th id="T_09241_level0_row2" class="row_heading level0 row2" >Vitamin B5 Defi...</th>
#       <td id="T_09241_row2_col0" class="data row2 col0" >0.74</td>
#       <td id="T_09241_row2_col1" class="data row2 col1" >0.83</td>
#       <td id="T_09241_row2_col2" class="data row2 col2" >0.79</td>
#       <td id="T_09241_row2_col3" class="data row2 col3" >253.00</td>
#     </tr>
#     <tr>
#       <th id="T_09241_level0_row3" class="row_heading level0 row3" >Vitamin B6 Defi...</th>
#       <td id="T_09241_row3_col0" class="data row3 col0" >0.78</td>
#       <td id="T_09241_row3_col1" class="data row3 col1" >0.48</td>
#       <td id="T_09241_row3_col2" class="data row3 col2" >0.59</td>
#       <td id="T_09241_row3_col3" class="data row3 col3" >98.00</td>
#     </tr>
#     <tr>
#       <th id="T_09241_level0_row4" class="row_heading level0 row4" >Vitamin B9 Defi...</th>
#       <td id="T_09241_row4_col0" class="data row4 col0" >0.89</td>
#       <td id="T_09241_row4_col1" class="data row4 col1" >0.99</td>
#       <td id="T_09241_row4_col2" class="data row4 col2" >0.94</td>
#       <td id="T_09241_row4_col3" class="data row4 col3" >282.00</td>
#     </tr>
#     <tr>
#       <th id="T_09241_level0_row5" class="row_heading level0 row5" >Vitamin C Defic...</th>
#       <td id="T_09241_row5_col0" class="data row5 col0" >0.74</td>
#       <td id="T_09241_row5_col1" class="data row5 col1" >0.77</td>
#       <td id="T_09241_row5_col2" class="data row5 col2" >0.75</td>
#       <td id="T_09241_row5_col3" class="data row5 col3" >327.00</td>
#     </tr>
#     <tr>
#       <th id="T_09241_level0_row6" class="row_heading level0 row6" >Vitamin K Defic...</th>
#       <td id="T_09241_row6_col0" class="data row6 col0" >0.98</td>
#       <td id="T_09241_row6_col1" class="data row6 col1" >0.91</td>
#       <td id="T_09241_row6_col2" class="data row6 col2" >0.94</td>
#       <td id="T_09241_row6_col3" class="data row6 col3" >345.00</td>
#     </tr>
#     <tr>
#       <th id="T_09241_level0_row7" class="row_heading level0 row7" >Iron Deficiency</th>
#       <td id="T_09241_row7_col0" class="data row7 col0" >0.80</td>
#       <td id="T_09241_row7_col1" class="data row7 col1" >0.70</td>
#       <td id="T_09241_row7_col2" class="data row7 col2" >0.75</td>
#       <td id="T_09241_row7_col3" class="data row7 col3" >239.00</td>
#     </tr>
#     <tr>
#       <th id="T_09241_level0_row8" class="row_heading level0 row8" >Protein Deficie...</th>
#       <td id="T_09241_row8_col0" class="data row8 col0" >0.75</td>
#       <td id="T_09241_row8_col1" class="data row8 col1" >0.77</td>
#       <td id="T_09241_row8_col2" class="data row8 col2" >0.76</td>
#       <td id="T_09241_row8_col3" class="data row8 col3" >294.00</td>
#     </tr>
#     <tr>
#       <th id="T_09241_level0_row9" class="row_heading level0 row9" >accuracy</th>
#       <td id="T_09241_row9_col0" class="data row9 col0" >0.81</td>
#       <td id="T_09241_row9_col1" class="data row9 col1" >0.81</td>
#       <td id="T_09241_row9_col2" class="data row9 col2" >0.81</td>
#       <td id="T_09241_row9_col3" class="data row9 col3" >0.81</td>
#     </tr>
#     <tr>
#       <th id="T_09241_level0_row10" class="row_heading level0 row10" >macro avg</th>
#       <td id="T_09241_row10_col0" class="data row10 col0" >0.79</td>
#       <td id="T_09241_row10_col1" class="data row10 col1" >0.78</td>
#       <td id="T_09241_row10_col2" class="data row10 col2" >0.78</td>
#       <td id="T_09241_row10_col3" class="data row10 col3" >1963.00</td>
#     </tr>
#     <tr>
#       <th id="T_09241_level0_row11" class="row_heading level0 row11" >weighted avg</th>
#       <td id="T_09241_row11_col0" class="data row11 col0" >0.81</td>
#       <td id="T_09241_row11_col1" class="data row11 col1" >0.81</td>
#       <td id="T_09241_row11_col2" class="data row11 col2" >0.81</td>
#       <td id="T_09241_row11_col3" class="data row11 col3" >1963.00</td>
#     </tr>
#   </tbody>
# </table>
